# %%
import json
import time
import pymongo
from pymongo import MongoClient

import random
import cassiopeia
from cassiopeia import riotapi
import cassiopeia.type.core.common as common

from collections import deque

riotapi.set_region("OCE")
riotapi.set_api_key("79428a9e-5d98-469b-9b9b-429c1a750d24")
riotapi.print_calls(True)
summoner = riotapi.get_summoner_by_name("smilming")
print "Name:" + summoner.name
print "Level:" + str(summoner.level)
print "ID:" + str(summoner.id)
# Out:
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/by-name/smilming?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# Name:smilming
# Level:30
# ID:2780130

# %%
masters = riotapi.get_master()
# Out:
# https://oce.api.pvp.net/api/lol/oce/v2.5/league/master?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24&type=RANKED_SOLO_5x5
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/555008,1132033,229379,1153622,627719,1582600,4461579,5540365,497679,7600144,638484,498717,367137,498210,1380903,324274,314888,5540914,1343028,3762231,1530424,578105,4560956,291902,1000512,380994,402614,2922593,319522,620617,724554,297036,2560269,6381137,554066,236630,3210839,4890200,579674,229981?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/285278,397919,5530208,402017,1505382,220270,399473,890994,399995,3700139,222336,453249,343682,774275,1363078,272065,508040,281749,323736,289945,2910362,6070946,620195,276134,329383,1321671,1160364,273070,402607,232626,6851253,303286,411324,293793,915141,431814,447687,632520,582861,272845?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/365776,319185,4802261,302301,369886,276609,3302634,294124,2492145,223474,458995,285428,3520130,561400,591612,511987,852897,397059,5500668,372999,1485066,303883,222477,475949,222994,234227,225571,941349,714534,480554,639275,237869,507474,1700156,1391421,593726,359746,553284,478024,603978?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/350540,308047,231252,365399,636251,331115,282476,230254,551283,2573886,702845,233854,349571,579980,288749,397204,230805,586137,467865,367514,479135,697761,632903,1260460,312239,239603,299446,479671,299452,6062154,701380,227574,1374113,481868,352205,2060238,590799,563153,324564,5943766?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/7840733,433631,6910949,556518,490984,1151228,637933,5991090,1691119,871409,6931955,486389,590676,554492?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24

# %%
def GetTierDivisionValue(tier, division):
    tierMap = {common.Tier.unranked: -1, common.Tier.bronze:0, common.Tier.silver:10, common.Tier.gold:20, common.Tier.platinum:30, common.Tier.diamond:40, common.Tier.master:50, common.Tier.challenger:60}
    divisionMap = {common.Division.one:8, common.Division.two:6, common.Division.three:4, common.Division.four:2, common.Division.five:0}
    tierValue = tierMap[tier]
    divisionValue = divisionMap[division]
    return tierValue + divisionValue
print GetTierDivisionValue(common.Tier.challenger, common.Division.one)
# Out:
# 68

# %%
print masters[0].division
print type(masters[0].division)
print masters[0].league_points
print type(masters.tier)
# Out:
# Division.one
# <enum 'Division'>
# 231
# <enum 'Tier'>

# %%
client = MongoClient()
loladb = client.loladb
summoners_collection = loladb.summoners
matches_collection = loladb.matches
leagues_collection = loladb.leagues

# %%
#print masters.data.to_json()
#print type(masters)
#league_dict = json.loads(masters.data.to_json())
#print current_summoner.name
#print current_summoner.id
print summoners_collection.count()
print leagues_collection.count()
print matches_collection.count()
#for smn in summoners_collection.find():
    #print smn
#print match_list[0].to_json()
#RecordSummonerLatestMatchId(current_summoner, match_list[0].id)
#print leagues_collection.find_one({})
# Out:
# 28
# 1
# 16314

# %%
def TrimMatchData(match):
    match['timeline'] = None
    
    if match['participants'] != None:
        for i, par in enumerate(match['participantIdentities']):
            par['championId'] = match['participants'][i]['championId']
            par['summonerId'] = par['player']['summonerId']
            par['role'] = match['participants'][i]['timeline']['role']
            par['lane'] = match['participants'][i]['timeline']['lane']
            par['player'] = None
        match['participants'] = None
    
    if match['teams'] != None:
        match['winner'] = -1
        if match['teams'][0]['winner'] == True:
            match['winner'] = 0
        if match['teams'][1]['winner'] == True:
            match['winner'] = 1
        match['teams'] = None

# %%
def RecordSummonerLatestMatchId(summoner, matchId):
    summoners_collection.update_one({'id':summoner.id}, {'$set': {'latestMatchId': matchId}})

def RecordSummonerForFullGrab(summoner):
    if summoners_collection.find_one({'id':summoner.id}) == None:
        summoner_dict = dict()
        summoner_dict['name'] = summoner.name
        summoner_dict['id'] = summoner.id
        summoner_dict['summonerLevel'] = summoner.data.summonerLevel
        summoner_dict['revisionDate'] = summoner.data.revisionDate
        summoner_dict['fullGrab'] = True
        summoners_collection.insert_one(summoner_dict)
    else:
        summoners_collection.update_one({'id':summoner.id}, {'$set': {'fullGrab': True}})
        

def IsLatestMatch(match_dict):
    if match_dict['season'] ==  "SEASON2017" or match_dict['season'] ==  "PRESEASON2017" or match_dict['season'] ==  "SEASON2016":
        return True
    else:
        return False

def IsSoloRank(match_type):
    if match_type == 'TEAM_BUILDER_RANKED_SOLO' or match_type == 'TEAM_BUILDER_DRAFT_RANKED_5x5':
        return True
    else:
        return False
    
def IsRequiredMatch(match_dict):
    if IsSoloRank(match_dict['queueType']) and match_dict['matchMode'] == 'CLASSIC' and match_dict['matchType'] == 'MATCHED_GAME':
        return True
    else:
        return False

def RecordMatchesForSummoner(summoner):
    fullGrabbed = False
    latestGrabbedMatchId = 0
    summoner_record = summoners_collection.find_one({'id':summoner.id})
    if summoner_record != None and summoner_record['fullGrab'] == True:
        fullGrabbed = True
        latestGrabbedMatchId = summoner_record['latestMatchId']
        
    match_list = summoner.match_list()
    list_size = len(match_list)
    print 'Match list number:' + str(list_size)
    for match_idx, match in enumerate(match_list):
        print 'processing %d - %d' % (match_idx, list_size)
        if fullGrabbed == True and match.id <= latestGrabbedMatchId:
            print 'Because we already full grabbed this summoner, break the loop while current match is already grabbed'
            if match_idx != 0:
                RecordSummonerLatestMatchId(summoner, match_list[0].id)
                time.sleep( 4 )
                print "wait 4 seconds"
            break
            
        if IsSoloRank(match.data.queue) == False:
            print 'Continue for not solo rank with id ' + str(match.id)
            print "wait 4 seconds"
            time.sleep( 4 )
            if match_idx == list_size - 1:
                #last one
                print 'Recording summoner for a full grab'
                RecordSummonerForFullGrab(summoner)
                RecordSummonerLatestMatchId(summoner, match_list[0].id)
            continue
            
        if matches_collection.find_one({'matchId':match.id}) == None:
            match_data = match.match()
            print "wait 4 seconds"
            time.sleep( 4 )
            match_dict = json.loads(match_data.to_json())
            TrimMatchData(match_dict)
            print match_dict['matchId']
            print match_dict['matchCreation']
            if IsLatestMatch(match_dict):
                if IsRequiredMatch(match_dict):
                    matches_collection.insert_one(match_dict)
                    print 'Match saved to db with id ' + str(match.id)
                else:
                    print 'Match not required with id ' + str(match.id)
            else:
                print 'Break for reaching outdated matches'
                print 'Recording summoner for a full grab'
                RecordSummonerForFullGrab(summoner)
                RecordSummonerLatestMatchId(summoner, match_list[0].id)
                break
        else:
            print 'Found match in db with id ' + str(match.id)

for entry in masters:
    current_summoner = entry.summoner
    try:
        RecordMatchesForSummoner(current_summoner)
    except (AttributeError, cassiopeia.type.api.exception.APIError) as apiError:
        print apiError
        print "Oops!  Error happened. Keep going..."
        print "wait 4 seconds"
        time.sleep( 4 )
# Out:
# https://oce.api.pvp.net/api/lol/oce/v2.2/matchlist/by-summoner/372999?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/matchlist/by-summoner/372999?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# Match list number:772
# processing 0 - 772
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/2360070795?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# Server returned error 404 on call: https://oce.api.pvp.net/api/lol/oce/v2.2/match/2360070795?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# Oops!  Error happened. Keep going...
# wait 4 seconds
# https://oce.api.pvp.net/api/lol/oce/v2.2/matchlist/by-summoner/222994?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/matchlist/by-summoner/222994?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/matchlist/by-summoner/222994?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# Match list number:1478
# processing 0 - 1478
# Because we already full grabbed this summoner, break the loop while current match is already grabbed
# https://oce.api.pvp.net/api/lol/oce/v2.2/matchlist/by-summoner/5500668?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# Match list number:696
# processing 0 - 696
# Because we already full grabbed this summoner, break the loop while current match is already grabbed
# https://oce.api.pvp.net/api/lol/oce/v2.2/matchlist/by-summoner/620195?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# Match list number:1301
# processing 0 - 1301
# Because we already full grabbed this summoner, break the loop while current match is already grabbed
# https://oce.api.pvp.net/api/lol/oce/v2.2/matchlist/by-summoner/915141?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/matchlist/by-summoner/915141?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# Match list number:1099
# processing 0 - 1099
# Because we already full grabbed this summoner, break the loop while current match is already grabbed
# https://oce.api.pvp.net/api/lol/oce/v2.2/matchlist/by-summoner/399995?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/matchlist/by-summoner/399995?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/matchlist/by-summoner/399995?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# Match list number:2300
# processing 0 - 2300
# Because we already full grabbed this summoner, break the loop while current match is already grabbed
# https://oce.api.pvp.net/api/lol/oce/v2.2/matchlist/by-summoner/231252?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# Match list number:3690
# processing 0 - 3690
# Found match in db with id 156097646
# processing 1 - 3690
# Found match in db with id 156087130
# processing 2 - 3690
# Found match in db with id 156086201
# processing 3 - 3690
# Found match in db with id 156095144
# processing 4 - 3690
# Found match in db with id 156084465
# processing 5 - 3690
# Found match in db with id 156083929
# processing 6 - 3690
# Found match in db with id 156083348
# processing 7 - 3690
# Found match in db with id 156092126
# processing 8 - 3690
# Found match in db with id 156081840
# processing 9 - 3690
# Found match in db with id 156081414
# processing 10 - 3690
# Found match in db with id 155943557
# processing 11 - 3690
# Found match in db with id 155942803
# processing 12 - 3690
# Found match in db with id 155932462
# processing 13 - 3690
# Found match in db with id 155941527
# processing 14 - 3690
# Found match in db with id 155717234
# processing 15 - 3690
# wait 4 seconds
# 155712013
# 1480081152133
# Match saved to db with id 155712013
# processing 16 - 3690
# Continue for not solo rank with id 155455350
# wait 4 seconds
# processing 17 - 3690
# Continue for not solo rank with id 155454747
# wait 4 seconds
# processing 18 - 3690
# Continue for not solo rank with id 155383551
# wait 4 seconds
# processing 19 - 3690
# Continue for not solo rank with id 155393052
# wait 4 seconds
# processing 20 - 3690
# Continue for not solo rank with id 155129795
# wait 4 seconds
# processing 21 - 3690
# Continue for not solo rank with id 155138406
# wait 4 seconds
# processing 22 - 3690
# Continue for not solo rank with id 155135636
# wait 4 seconds
# processing 23 - 3690
# Continue for not solo rank with id 155077937
# wait 4 seconds
# processing 24 - 3690
# Continue for not solo rank with id 155077297
# wait 4 seconds
# processing 25 - 3690
# Continue for not solo rank with id 154926757
# wait 4 seconds
# processing 26 - 3690
# Continue for not solo rank with id 154935613
# wait 4 seconds
# processing 27 - 3690
# Continue for not solo rank with id 154934805
# wait 4 seconds
# processing 28 - 3690
# Continue for not solo rank with id 154922154
# wait 4 seconds
# processing 29 - 3690
# Continue for not solo rank with id 154930881
# wait 4 seconds
# processing 30 - 3690
# Continue for not solo rank with id 154920258
# wait 4 seconds
# processing 31 - 3690
# Continue for not solo rank with id 154864518
# wait 4 seconds
# processing 32 - 3690
# Continue for not solo rank with id 154854059
# wait 4 seconds
# processing 33 - 3690
# Continue for not solo rank with id 154863093
# wait 4 seconds
# processing 34 - 3690
# Continue for not solo rank with id 154852471
# wait 4 seconds
# processing 35 - 3690
# Continue for not solo rank with id 154851682
# wait 4 seconds
# processing 36 - 3690
# Continue for not solo rank with id 154789695
# wait 4 seconds
# processing 37 - 3690
# Continue for not solo rank with id 154787727
# wait 4 seconds
# processing 38 - 3690
# Continue for not solo rank with id 154785948
# wait 4 seconds
# processing 39 - 3690
# Continue for not solo rank with id 154775479
# wait 4 seconds
# processing 40 - 3690
# Continue for not solo rank with id 154775366
# wait 4 seconds
# processing 41 - 3690
# Continue for not solo rank with id 154774972
# wait 4 seconds
# processing 42 - 3690
# Continue for not solo rank with id 154771949
# wait 4 seconds
# processing 43 - 3690
# Continue for not solo rank with id 154771315
# wait 4 seconds
# processing 44 - 3690
# Continue for not solo rank with id 154780538
# wait 4 seconds
# processing 45 - 3690
# Continue for not solo rank with id 154669610
# wait 4 seconds
# processing 46 - 3690
# Continue for not solo rank with id 154665720
# wait 4 seconds
# processing 47 - 3690
# Continue for not solo rank with id 154665347
# wait 4 seconds
# processing 48 - 3690
# Continue for not solo rank with id 154651160
# wait 4 seconds
# processing 49 - 3690
# Continue for not solo rank with id 154650647
# wait 4 seconds
# processing 50 - 3690
# Continue for not solo rank with id 154589697
# wait 4 seconds
# processing 51 - 3690
# Continue for not solo rank with id 154589049
# wait 4 seconds
# processing 52 - 3690
# Continue for not solo rank with id 154588528
# wait 4 seconds
# processing 53 - 3690
# Continue for not solo rank with id 154577889
# wait 4 seconds
# processing 54 - 3690
# Continue for not solo rank with id 154580281
# wait 4 seconds
# processing 55 - 3690
# Continue for not solo rank with id 154519734
# wait 4 seconds
# processing 56 - 3690
# Continue for not solo rank with id 154515916
# wait 4 seconds
# processing 57 - 3690
# Continue for not solo rank with id 154505254
# wait 4 seconds
# processing 58 - 3690
# Continue for not solo rank with id 154504642
# wait 4 seconds
# processing 59 - 3690
# Continue for not solo rank with id 154513940
# wait 4 seconds
# processing 60 - 3690
# Continue for not solo rank with id 154513297
# wait 4 seconds
# processing 61 - 3690
# Continue for not solo rank with id 154502680
# wait 4 seconds
# processing 62 - 3690
# Continue for not solo rank with id 154512342
# wait 4 seconds
# processing 63 - 3690
# Continue for not solo rank with id 154501153
# wait 4 seconds
# processing 64 - 3690
# Continue for not solo rank with id 154346096
# wait 4 seconds
# processing 65 - 3690
# Continue for not solo rank with id 154336158
# wait 4 seconds
# processing 66 - 3690
# Continue for not solo rank with id 154343812
# wait 4 seconds
# processing 67 - 3690
# Continue for not solo rank with id 154343200
# wait 4 seconds
# processing 68 - 3690
# Continue for not solo rank with id 154332984
# wait 4 seconds
# processing 69 - 3690
# Continue for not solo rank with id 154276981
# wait 4 seconds
# processing 70 - 3690
# Continue for not solo rank with id 154267246
# wait 4 seconds
# processing 71 - 3690
# Continue for not solo rank with id 154276520
# wait 4 seconds
# processing 72 - 3690
# Continue for not solo rank with id 154266697
# wait 4 seconds
# processing 73 - 3690
# Continue for not solo rank with id 154265875
# wait 4 seconds
# processing 74 - 3690
# Continue for not solo rank with id 154274778
# wait 4 seconds
# processing 75 - 3690
# Continue for not solo rank with id 154273986
# wait 4 seconds
# processing 76 - 3690
# Continue for not solo rank with id 154139415
# wait 4 seconds
# processing 77 - 3690
# Continue for not solo rank with id 154138748
# wait 4 seconds
# processing 78 - 3690
# Continue for not solo rank with id 154137996
# wait 4 seconds
# processing 79 - 3690
# Continue for not solo rank with id 154136956
# wait 4 seconds
# processing 80 - 3690
# Continue for not solo rank with id 154136151
# wait 4 seconds
# processing 81 - 3690
# Continue for not solo rank with id 154135310
# wait 4 seconds
# processing 82 - 3690
# Continue for not solo rank with id 154132237
# wait 4 seconds
# processing 83 - 3690
# Continue for not solo rank with id 154131595
# wait 4 seconds
# processing 84 - 3690
# Continue for not solo rank with id 154140374
# wait 4 seconds
# processing 85 - 3690
# Continue for not solo rank with id 154059982
# wait 4 seconds
# processing 86 - 3690
# Continue for not solo rank with id 154059351
# wait 4 seconds
# processing 87 - 3690
# Continue for not solo rank with id 154058639
# wait 4 seconds
# processing 88 - 3690
# Continue for not solo rank with id 154067816
# wait 4 seconds
# processing 89 - 3690
# Continue for not solo rank with id 154067119
# wait 4 seconds
# processing 90 - 3690
# Continue for not solo rank with id 154056824
# wait 4 seconds
# processing 91 - 3690
# Continue for not solo rank with id 154056232
# wait 4 seconds
# processing 92 - 3690
# Continue for not solo rank with id 154065302
# wait 4 seconds
# processing 93 - 3690
# Continue for not solo rank with id 154055266
# wait 4 seconds
# processing 94 - 3690
# Continue for not solo rank with id 154054179
# wait 4 seconds
# processing 95 - 3690
# Continue for not solo rank with id 154063014
# wait 4 seconds
# processing 96 - 3690
# Continue for not solo rank with id 154052407
# wait 4 seconds
# processing 97 - 3690
# Continue for not solo rank with id 153925712
# wait 4 seconds
# processing 98 - 3690
# Continue for not solo rank with id 153924905
# wait 4 seconds
# processing 99 - 3690
# Continue for not solo rank with id 153924116
# wait 4 seconds
# processing 100 - 3690
# Continue for not solo rank with id 153912765
# wait 4 seconds
# processing 101 - 3690
# Continue for not solo rank with id 153921898
# wait 4 seconds
# processing 102 - 3690
# Continue for not solo rank with id 153921316
# wait 4 seconds
# processing 103 - 3690
# Continue for not solo rank with id 153920697
# wait 4 seconds
# processing 104 - 3690
# Continue for not solo rank with id 153910371
# wait 4 seconds
# processing 105 - 3690
# Continue for not solo rank with id 153839700
# wait 4 seconds
# processing 106 - 3690
# Continue for not solo rank with id 153828965
# wait 4 seconds
# processing 107 - 3690
# Continue for not solo rank with id 153836421
# wait 4 seconds
# processing 108 - 3690
# Continue for not solo rank with id 153836054
# wait 4 seconds
# processing 109 - 3690
# Continue for not solo rank with id 153835078
# wait 4 seconds
# processing 110 - 3690
# Continue for not solo rank with id 153834682
# wait 4 seconds
# processing 111 - 3690
# Continue for not solo rank with id 153824291
# wait 4 seconds
# processing 112 - 3690
# Continue for not solo rank with id 153823770
# wait 4 seconds
# processing 113 - 3690
# Continue for not solo rank with id 153823194
# wait 4 seconds
# processing 114 - 3690
# Continue for not solo rank with id 153831802
# wait 4 seconds
# processing 115 - 3690
# Continue for not solo rank with id 153831396
# wait 4 seconds
# processing 116 - 3690
# Continue for not solo rank with id 153830180
# wait 4 seconds
# processing 117 - 3690
# Continue for not solo rank with id 153699979
# wait 4 seconds
# processing 118 - 3690
# Continue for not solo rank with id 153699758
# wait 4 seconds
# processing 119 - 3690
# Continue for not solo rank with id 153689253
# wait 4 seconds
# processing 120 - 3690
# Continue for not solo rank with id 153689012
# wait 4 seconds
# processing 121 - 3690
# Continue for not solo rank with id 153698792
# wait 4 seconds
# processing 122 - 3690
# Continue for not solo rank with id 153688490
# wait 4 seconds
# processing 123 - 3690
# Continue for not solo rank with id 153683991
# wait 4 seconds
# processing 124 - 3690
# Continue for not solo rank with id 153693530
# wait 4 seconds
# processing 125 - 3690
# Continue for not solo rank with id 153693028
# wait 4 seconds
# processing 126 - 3690
# Continue for not solo rank with id 153681600
# wait 4 seconds
# processing 127 - 3690
# Continue for not solo rank with id 153681394
# wait 4 seconds
# processing 128 - 3690
# Continue for not solo rank with id 153681190
# wait 4 seconds
# processing 129 - 3690
# Continue for not solo rank with id 153690746
# wait 4 seconds
# processing 130 - 3690
# Continue for not solo rank with id 153690533
# wait 4 seconds
# processing 131 - 3690
# Continue for not solo rank with id 153690357
# wait 4 seconds
# processing 132 - 3690
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/152974073?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/152974073?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/152974073?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/152974073?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/368961,707970,280161,681355,325988?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# wait 4 seconds
# 152974073
# 1478228891964
# Match saved to db with id 152974073
# processing 133 - 3690
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/152526463?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/7802039,228153,749115,230847?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# wait 4 seconds
# 152526463
# 1477884625964
# Match saved to db with id 152526463
# processing 134 - 3690
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/152525551?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/152525551?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/152525551?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/568000,5090275,5440634,326206?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# wait 4 seconds
# 152525551
# 1477877853996
# Match saved to db with id 152525551
# processing 135 - 3690
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/152425807?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/152425807?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/330947,320586,322636,3610141,222739,448671?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# wait 4 seconds
# 152425807
# 1477806505185
# Match saved to db with id 152425807
# processing 136 - 3690
# Found match in db with id 152069184
# processing 137 - 3690
# Found match in db with id 151936837
# processing 138 - 3690
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/151795829?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/285512,709795,274168,630236?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# wait 4 seconds
# 151795829
# 1477296562547
# Match saved to db with id 151795829
# processing 139 - 3690
# Found match in db with id 151650380
# processing 140 - 3690
# Found match in db with id 151559933
# processing 141 - 3690
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/151559276?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/630149,715180,338158,287443,282334?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# wait 4 seconds
# 151559276
# 1477192186582
# Match saved to db with id 151559276
# processing 142 - 3690
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/151568646?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/151568646?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/151568646?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/493115?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# wait 4 seconds
# 151568646
# 1477190074442
# Match saved to db with id 151568646
# processing 143 - 3690
# Found match in db with id 151558193
# processing 144 - 3690
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/151557728?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/151557728?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/890992,3663783,2752680,397616,723286,8060158?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# wait 4 seconds
# 151557728
# 1477183794036
# Match saved to db with id 151557728
# processing 145 - 3690
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/151557400?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/831138,236461,455957,397787?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# wait 4 seconds
# 151557400
# 1477181174031
# Match saved to db with id 151557400
# processing 146 - 3690
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/151467451?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/151467451?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/3312650,321007,2732496,7811697,479574,1864028?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# wait 4 seconds
# 151467451
# 1477115982977
# Match saved to db with id 151467451
# processing 147 - 3690
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/151466868?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/151466868?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/1494794,2651026,236887,918072?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# wait 4 seconds
# 151466868
# 1477113432828
# Match saved to db with id 151466868
# processing 148 - 3690
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/151466217?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/6870208,232755,8050173?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# wait 4 seconds
# 151466217
# 1477110389410
# Match saved to db with id 151466217
# processing 149 - 3690
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/151465235?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/151465235?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/3661252,579944,405709,2911476,476851,290169?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# wait 4 seconds
# 151465235
# 1477104562465
# Match saved to db with id 151465235
# processing 150 - 3690
# Found match in db with id 151474797
# processing 151 - 3690
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/151464441?includeTimeline=True&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://oce.api.pvp.net/api/lol/oce/v1.4/summoner/7491044,592700,437713,626793,7731924,1270780?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# wait 4 seconds
# 151464441
# 1477098597771
# Match saved to db with id 151464441
# processing 152 - 3690
# Found match in db with id 151464083
# processing 153 - 3690
# https://oce.api.pvp.net/api/lol/oce/v2.2/match/
seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-b872ca7cc6af> in <module>()
#      91     current_summoner = entry.summoner
#      92     try:
# ---> 93         RecordMatchesForSummoner(current_summoner)
#      94     except (AttributeError, cassiopeia.type.api.exception.APIError) as apiError:
#      95         print apiError
#
# <ipython-input-13-b872ca7cc6af> in RecordMatchesForSummoner(summoner)
#      68             match_data = match.match()
#      69             print "wait 4 seconds"
# ---> 70             time.sleep( 4 )
#      71             match_dict = json.loads(match_data.to_json())
#      72             TrimMatchData(match_dict)
#
# KeyboardInterrupt:

# %%
match_list = current_summoner.match_list()
print len(match_list)
match = match_list[0].match()
match_dict = json.loads(match.to_json())
TrimMatchData(match_dict)
print json.dumps(match_dict)
# Out:
# https://oce.api.pvp.net/api/lol/oce/v2.2/matchlist/by-summoner/503773?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# 812
# {"winner": 1, "participantIdentities": [{"player": null, "championId": 64, "participantId": 1, "summonerId": 220201}, {"player": null, "championId": 81, "participantId": 2, "summonerId": 568000}, {"player": null, "championId": 150, "participantId": 3, "summonerId": 479135}, {"player": null, "championId": 7, "participantId": 4, "summonerId": 230726}, {"player": null, "championId": 223, "participantId": 5, "summonerId": 503773}, {"player": null, "championId": 60, "participantId": 6, "summonerId": 411324}, {"player": null, "championId": 201, "participantId": 7, "summonerId": 483862}, {"player": null, "championId": 127, "participantId": 8, "summonerId": 3490137}, {"player": null, "championId": 18, "participantId": 9, "summonerId": 233721}, {"player": null, "championId": 57, "participantId": 10, "summonerId": 365399}], "matchVersion": "6.23.166.2676", "platformId": "OC1", "season": "PRESEASON2017", "region": "OCE", "matchId": 155446400, "mapId": 11, "matchCreation": 1479895810169, "teams": null, "participants": null, "matchMode": "CLASSIC", "matchDuration": 1693, "timeline": null, "queueType": "TEAM_BUILDER_RANKED_SOLO", "matchType": "MATCHED_GAME"}

# %%
print matches_collection.find_one({'matchId':154857985})
# Out:
# {u'matchId': 154857985, u'participantIdentities': [{u'lane': u'BOTTOM', u'championId': 67, u'participantId': 1, u'player': None, u'role': u'DUO_CARRY', u'summonerId': 3762231}, {u'lane': u'MIDDLE', u'championId': 81, u'participantId': 2, u'player': None, u'role': u'SOLO', u'summonerId': 314889}, {u'lane': u'JUNGLE', u'championId': 121, u'participantId': 3, u'player': None, u'role': u'NONE', u'summonerId': 1582600}, {u'lane': u'BOTTOM', u'championId': 40, u'participantId': 4, u'player': None, u'role': u'DUO_SUPPORT', u'summonerId': 444705}, {u'lane': u'TOP', u'championId': 157, u'participantId': 5, u'player': None, u'role': u'SOLO', u'summonerId': 334421}, {u'lane': u'JUNGLE', u'championId': 64, u'participantId': 6, u'player': None, u'role': u'NONE', u'summonerId': 601923}, {u'lane': u'BOTTOM', u'championId': 412, u'participantId': 7, u'player': None, u'role': u'DUO_SUPPORT', u'summonerId': 503773}, {u'lane': u'MIDDLE', u'championId': 103, u'participantId': 8, u'player': None, u'role': u'SOLO', u'summonerId': 620617}, {u'lane': u'BOTTOM', u'championId': 236, u'participantId': 9, u'player': None, u'role': u'DUO_CARRY', u'summonerId': 330947}, {u'lane': u'TOP', u'championId': 48, u'participantId': 10, u'player': None, u'role': u'SOLO', u'summonerId': 323242}], u'matchVersion': u'6.22.165.9605', u'platformId': u'OC1', u'season': u'PRESEASON2017', u'region': u'OCE', u'winner': 0, u'mapId': 11, u'matchCreation': 1479515144621L, u'teams': None, u'participants': None, u'matchMode': u'CLASSIC', u'matchDuration': 1661, u'timeline': None, u'queueType': u'TEAM_BUILDER_RANKED_SOLO', u'matchType': u'MATCHED_GAME', u'_id': ObjectId('58361817666d596ebfc62350')}

# %%
print current_summoner.id
print current_summoner.name
# Out:
# 503773
# NADA1001

# %%
if leagues_collection.find_one({'name':league_dict['name']}) == None:
    leagues_collection.insert_one(dict(league_dict))
else:
    print 'League already exists'
#print leagues_collection.find_one({name })
# Out:
# League already exists

# %%
match_list = summoner.match_list()
print len(match_list)
match = match_list[0].match()
match_without_timeline = json.loads(match.to_json())
        
TrimMatchData(match_without_timeline)
print json.dumps(match_without_timeline)
# Out:
# https://oce.api.pvp.net/api/lol/oce/v2.2/matchlist/by-summoner/2780130?api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# 1638
# {"winner": 1, "participantIdentities": [{"lane": "TOP", "championId": 106, "participantId": 1, "player": null, "role": "SOLO", "summonerId": 230978}, {"lane": "MIDDLE", "championId": 99, "participantId": 2, "player": null, "role": "SOLO", "summonerId": 2780130}, {"lane": "BOTTOM", "championId": 15, "participantId": 3, "player": null, "role": "DUO_CARRY", "summonerId": 5821224}, {"lane": "BOTTOM", "championId": 412, "participantId": 4, "player": null, "role": "DUO_SUPPORT", "summonerId": 3163357}, {"lane": "JUNGLE", "championId": 76, "participantId": 5, "player": null, "role": "NONE", "summonerId": 289863}, {"lane": "BOTTOM", "championId": 21, "participantId": 6, "player": null, "role": "DUO_CARRY", "summonerId": 2952658}, {"lane": "MIDDLE", "championId": 25, "participantId": 7, "player": null, "role": "SOLO", "summonerId": 271698}, {"lane": "BOTTOM", "championId": 78, "participantId": 8, "player": null, "role": "DUO_SUPPORT", "summonerId": 347625}, {"lane": "TOP", "championId": 122, "participantId": 9, "player": null, "role": "SOLO", "summonerId": 355446}, {"lane": "JUNGLE", "championId": 62, "participantId": 10, "player": null, "role": "NONE", "summonerId": 4950791}], "matchVersion": "6.23.166.2676", "platformId": "OC1", "season": "PRESEASON2017", "region": "OCE", "matchId": 155530071, "mapId": 11, "matchCreation": 1479924389696, "teams": null, "participants": null, "matchMode": "CLASSIC", "matchDuration": 2104, "timeline": null, "queueType": "TEAM_BUILDER_RANKED_SOLO", "matchType": "MATCHED_GAME"}

# %%
print match.id
# Out:
# 155530071

# %%
test_summoner = masters[0].summoner
print test_summoner.name
print test_summoner.id
print test_summoner.data.summonerLevel
print test_summoner.data.revisionDate
print league_dict.tier
print test_summoner.data.division
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-64955169c9c9> in <module>()
# ----> 1 test_summoner = masters[0].summoner
#       2 print test_summoner.name
#       3 print test_summoner.id
#       4 print test_summoner.data.summonerLevel
#       5 print test_summoner.data.revisionDate
#
# NameError: name 'masters' is not defined

# %%
summoner_dict = dict()
summoner_dict['name'] = test_summoner.name
summoner_dict['id'] = test_summoner.id
summoner_dict['summonerLevel'] = test_summoner.data.summonerLevel
summoner_dict['revisionDate'] = test_summoner.data.revisionDate

# %%
print summoners_collection.find_one({})
# Out:
# None

# %%
summoners_collection.insert_one(summoner_dict)

# %%
#show all entries
for entry in summoners_collection.find():
    print entry
# Out:
# {u'id': 372999, u'_id': ObjectId('583502eb666d59386fcd9192'), u'revisionDate': 1479534704000L, u'name': u'cat and bird', u'summonerLevel': 30}

# %%
#delete all entries
summoners_collection.delete_many({})

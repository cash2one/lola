# %%
import json
import time
import random
import pymongo
import copy
import MyCommon
from pymongo import MongoClient
from collections import deque
import cassiopeia
from cassiopeia import riotapi
import numpy as np
from sklearn import preprocessing, cluster, decomposition
from scipy.cluster.vq import kmeans,vq
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans, AffinityPropagation
from sklearn.decomposition import FastICA, PCA
from sklearn import metrics
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup

riotapi.set_region("OCE")
riotapi.set_api_key("79428a9e-5d98-469b-9b9b-429c1a750d24")
riotapi.set_rate_limits((10, 10), (500, 600))
riotapi.print_calls(False)

# %%
client = MongoClient()
loladb = client.loladb77
summoners_collection = loladb.summoners
matches_collection = loladb.matches

# %%
first_player = {}
first_player["name"] = "lolago"
first_player["id"] = ""
first_player["checked"] = False

if summoners_collection.find_one({'name':first_player["name"]}) == None:
    summoners_collection.insert_one(first_player)

# %%
#search for players based on game history
PLAYER_URL = "https://oce.op.gg/summoner/userName=%s"
DETAIL_URL = "https://oce.op.gg/summoner/matches/ajax/detail/gameId=%s&summonerId=%s"

current_summoner = None
for a_idx, a_summoner in enumerate(summoners_collection.find()):
    if a_summoner["checked"] == False:
        current_summoner = a_summoner
        break
        
starting_url = PLAYER_URL % current_summoner["name"]
print starting_url
r = requests.get(starting_url)
soup = BeautifulSoup(r.text, 'html.parser')
# Out:
# https://oce.op.gg/summoner/userName=Having Fun

# %%
def GetRowInfo(a_row):
    champion_name = a_row.find("td", class_="ChampionImage").find("a").find("div").text
    #print champion_name
    player_name = a_row.find("td", class_="SummonerName").find("a").text
    #print player_name
    player_tier = a_row.find("td", class_="Tier").text.strip()
    #print player_tier
    return (champion_name, player_name, player_tier)

def AddTeam(a_team):
    for a_member in a_team:
        a_summoner = {}
        a_summoner["name"] = a_member["player_name"]
        a_summoner["id"] = ""
        a_summoner["checked"] = False
        if summoners_collection.find_one({'name':a_summoner["name"]}) == None:
            summoners_collection.insert_one(a_summoner)

# %%
def CheckCurrentPlayer(current_summoner):
    starting_url = PLAYER_URL % current_summoner["name"]
    print starting_url
    r = requests.get(starting_url)
    soup = BeautifulSoup(r.text, 'html.parser')
    match_list_block = soup.find("div", class_="GameItemList")
    blocks = match_list_block.find_all("div", class_="GameItemWrap")
    for a_block_idx, a_block in enumerate(blocks):
        game_item = a_block.find("div", class_="GameItem")

        game_result_part = a_block.find("div", class_="GameStats")
        game_result = game_result_part.find("div", class_="GameResult")
        game_result_text = game_result.text.strip()
        if game_result_text == "Remake":
            continue

        game_type_text = game_result_part.find("div", class_="GameType").text.strip()
        if game_type_text != "Ranked Solo":
            continue

        stats_button = game_item.find("div", class_="StatsButton")
        stats_link = stats_button.find_all("a")[-1]
        stats_content = stats_link.attrs['onclick']
        stats_list = stats_content.split("(")[1].split(")")[0].split(",")

        game_id = stats_list[0].lstrip()
        summoner_id = stats_list[1].lstrip()

        current_summoner["id"] = summoner_id

        match_record = {}
        match_record["match_id"]= game_id

        match_url = DETAIL_URL % (game_id, summoner_id)
        print a_block_idx, match_url

        detail_r = requests.get(match_url)
        detail_soup = BeautifulSoup(detail_r.text, 'html.parser')

        detail_div = detail_soup.find("div", class_="GameDetailTableWrap")
        detail_tables = detail_div.find_all("table", class_="GameDetailTable")
        blue_win = detail_tables[0].attrs['class'][1] == 'Result-WIN'

        if blue_win:
            match_record["match_winner"] = 0
        else:
            match_record["match_winner"] = 1

        blue_team = []
        red_team = []
        blue_rows = detail_tables[0].find_all("tr", class_="Row")
        #row 1~5 are players stats
        for a_row_index in range(1, 6):
            a_row = blue_rows[a_row_index]
            (champion_name, player_name, player_tier) = GetRowInfo(a_row)
            blue_team.append({"champion_name":champion_name, "player_name":player_name, "player_tier":player_tier})
        red_rows = detail_tables[1].find_all("tr", class_="Row")
        for a_row_index in range(1, 6):
            a_row = red_rows[a_row_index]
            (champion_name, player_name, player_tier) = GetRowInfo(a_row)
            red_team.append({"champion_name":champion_name, "player_name":player_name, "player_tier":player_tier})

        match_record["blue_team"] = blue_team
        match_record["red_team"] = red_team

        AddTeam(blue_team)
        AddTeam(red_team)

        #print match_record
        if matches_collection.find_one({'match_id':match_record["match_id"]}) == None:
            matches_collection.insert_one(match_record)

    summoners_collection.update_one({'name':current_summoner["name"]}, {'$set': {'id': current_summoner["id"]}})
    summoners_collection.update_one({'name':current_summoner["name"]}, {'$set': {'checked': True}})

# %%
while True:
    current_summoner = None
    for a_idx, a_summoner in enumerate(summoners_collection.find()):
        if a_summoner["checked"] == False:
            current_summoner = a_summoner
            break
    if current_summoner == None:
        break
    print "Checking " + current_summoner["name"]
    CheckCurrentPlayer(current_summoner)
# Out:
# Checking Having Fun
# https://oce.op.gg/summoner/userName=Having Fun
# Checking Swishpop
# https://oce.op.gg/summoner/userName=Swishpop
# Checking Fear Of Heart
# https://oce.op.gg/summoner/userName=Fear Of Heart
# Checking Karlcccc
# https://oce.op.gg/summoner/userName=Karlcccc
# Checking toa
# https://oce.op.gg/summoner/userName=toa
# Checking cautious
# https://oce.op.gg/summoner/userName=cautious
# Checking Enûma Elišh
# https://oce.op.gg/summoner/userName=Enûma Elišh
# Checking kingLexsai
# https://oce.op.gg/summoner/userName=kingLexsai
# Checking RoFlCaKe95
# https://oce.op.gg/summoner/userName=RoFlCaKe95
# Checking ReRoyst
# https://oce.op.gg/summoner/userName=ReRoyst
# Checking mercy pl0x
# https://oce.op.gg/summoner/userName=mercy pl0x
# Checking Willma Fingerdoo
# https://oce.op.gg/summoner/userName=Willma Fingerdoo
# Checking Kill Secure
# https://oce.op.gg/summoner/userName=Kill Secure
# Checking Izaacmizac
# https://oce.op.gg/summoner/userName=Izaacmizac
# Checking TSM Wildturtle
# https://oce.op.gg/summoner/userName=TSM Wildturtle
# Checking Detective Long
# https://oce.op.gg/summoner/userName=Detective Long
# Checking Tatl
# https://oce.op.gg/summoner/userName=Tatl
# Checking Cimehox
# https://oce.op.gg/summoner/userName=Cimehox
# Checking D E A D  C I T Y
# https://oce.op.gg/summoner/userName=D E A D  C I T Y
# Checking Vongola Primo
# https://oce.op.gg/summoner/userName=Vongola Primo
# Checking creeptide
# https://oce.op.gg/summoner/userName=creeptide
# Checking Innersqt
# https://oce.op.gg/summoner/userName=Innersqt
# Checking kanghongwei
# https://oce.op.gg/summoner/userName=kanghongwei
# Checking KINGkim
# https://oce.op.gg/summoner/userName=KINGkim
# Checking drlordwars
# https://oce.op.gg/summoner/userName=drlordwars
# Checking SoloAN
# https://oce.op.gg/summoner/userName=SoloAN
# Checking Swop2333
# https://oce.op.gg/summoner/userName=Swop2333
# Checking Linkin Park
# https://oce.op.gg/summoner/userName=Linkin Park
# Checking nulixuexi
# https://oce.op.gg/summoner/userName=nulixuexi
# Checking Ðizzy
# https://oce.op.gg/summoner/userName=Ðizzy
# Checking Disheartened
# https://oce.op.gg/summoner/userName=Disheartened
# Checking I Am Boosted
# https://oce.op.gg/summoner/userName=I Am Boosted
# Checking likeajoke
# https://oce.op.gg/summoner/userName=likeajoke
# Checking mistar
# https://oce.op.gg/summoner/userName=mistar
# Checking JokerDaDi
# https://oce.op.gg/summoner/userName=JokerDaDi
# Checking Aykayel
# https://oce.op.gg/summoner/userName=Aykayel
# Checking Neis
# https://oce.op.gg/summoner/userName=Neis
# Checking Killerheart1234
# https://oce.op.gg/summoner/userName=Killerheart1234
# Checking Sundance almight
# https://oce.op.gg/summoner/userName=Sundance almight
# Checking Tenacity2016
# https://oce.op.gg/summoner/userName=Tenacity2016
# Checking dominicthedemon
# https://oce.op.gg/summoner/userName=dominicthedemon
# Checking Mybo
# https://oce.op.gg/summoner/userName=Mybo
# Checking League0fLesbians
# https://oce.op.gg/summoner/userName=League0fLesbians
# Checking Battleaxe22
# https://oce.op.gg/summoner/userName=Battleaxe22
# Checking Plz Diddly Meh
# https://oce.op.gg/summoner/userName=Plz Diddly Meh
# Checking MrOKaiGreene
# https://oce.op.gg/summoner/userName=MrOKaiGreene
# Checking CarryMike
# https://oce.op.gg/summoner/userName=CarryMike
# Checking XECUTRX
# https://oce.op.gg/summoner/userName=XECUTRX
# Checking Little Bear
# https://oce.op.gg/summoner/userName=Little Bear
# Checking Sõna
# https://oce.op.gg/summoner/userName=Sõna
# Checking Accelerator
# https://oce.op.gg/summoner/userName=Accelerator
# Checking Lyemeze
# https://oce.op.gg/summoner/userName=Lyemeze
# Checking Eugene666
# https://oce.op.gg/summoner/userName=Eugene666
# Checking FXY so naughty
# https://oce.op.gg/summoner/userName=FXY so naughty
# Checking Vir
# https://oce.op.gg/summoner/userName=Vir
# Checking xSolox
# https://oce.op.gg/summoner/userName=xSolox
# Checking On tragedy
# https://oce.op.gg/summoner/userName=On tragedy
# Checking juiceZPA
# https://oce.op.gg/summoner/userName=juiceZPA
# Checking Jhonny
# https://oce.op.gg/summoner/userName=Jhonny
# Checking Pierogi Boy
# https://oce.op.gg/summoner/userName=Pierogi Boy
# Checking SlowTeamV
# https://oce.op.gg/summoner/userName=SlowTeamV
# Checking PolarBearElite
# https://oce.op.gg/summoner/userName=PolarBearElite
# Checking Žero
# https://oce.op.gg/summoner/userName=Žero
# Checking Heavendoom7
# https://oce.op.gg/summoner/userName=Heavendoom7
# Checking Dominant Male
# https://oce.op.gg/summoner/userName=Dominant Male
# Checking Nevskii
# https://oce.op.gg/summoner/userName=Nevskii
# Checking Professor Frank
# https://oce.op.gg/summoner/userName=Professor Frank
# Checking Chooex
# https://oce.op.gg/summoner/userName=Chooex
# Checking MagusXreaper
# https://oce.op.gg/summoner/userName=MagusXreaper
# Checking Bernon
# https://oce.op.gg/summoner/userName=Bernon
# Checking l3obcat
# https://oce.op.gg/summoner/userName=l3obcat
# Checking Viivek
# https://oce.op.gg/summoner/userName=Viivek
# Checking Holden Makok
# https://oce.op.gg/summoner/userName=Holden Makok
# Checking Mrßlîšś Fåñßøÿ
# https://oce.op.gg/summoner/userName=Mrßlîšś Fåñßøÿ
# Checking TehNinjaa
# https://oce.op.gg/summoner/userName=TehNinjaa
# Checking Dr Du
# https://oce.op.gg/summoner/userName=Dr Du
# Checking al hasheous
# https://oce.op.gg/summoner/userName=al hasheous
# Checking AlcoPerry
# https://oce.op.gg/summoner/userName=AlcoPerry
# Checking Bamon
# https://oce.op.gg/summoner/userName=Bamon
# Checking aGary
# https://oce.op.gg/summoner/userName=aGary
# Checking I main Ao Shin
# https://oce.op.gg/summoner/userName=I main Ao Shin
# Checking oneweek
# https://oce.op.gg/summoner/userName=oneweek
# Checking Paradoxzy
# https://oce.op.gg/summoner/userName=Paradoxzy
# Checking IRLjesus
# https://oce.op.gg/summoner/userName=IRLjesus
# Checking Virilhitus
# https://oce.op.gg/summoner/userName=Virilhitus
# Checking Its high noot
# https://oce.op.gg/summoner/userName=Its high noot
# Checking ShizukaShi
# https://oce.op.gg/summoner/userName=ShizukaShi
# Checking nic579
# https://oce.op.gg/summoner/userName=nic579
# Checking Mount Tibet
# https://oce.op.gg/summoner/userName=Mount Tibet
# Checking BerserkerCC
# https://oce.op.gg/summoner/userName=BerserkerCC
# Checking XXP
# https://oce.op.gg/summoner/userName=XXP
# Checking ElementElite
# https://oce.op.gg/summoner/userName=ElementElite
# Checking TheRealMaje
# https://oce.op.gg/summoner/userName=TheRealMaje
# Checking TheRealIssue
# https://oce.op.gg/summoner/userName=TheRealIssue
# Checking Kyokushin
# https://oce.op.gg/summoner/userName=Kyokushin
# Checking Black Hawk
# https://oce.op.gg/summoner/userName=Black Hawk
# Checking Z Miao
# https://oce.op.gg/summoner/userName=Z Miao
# Checking PossessedTeddy
# https://oce.op.gg/summoner/userName=PossessedTeddy
# Checking Carry he jul ge
# https://oce.op.gg/summoner/userName=Carry he jul ge
# Checking GGImmaBigBoy
# https://oce.op.gg/summoner/userName=GGImmaBigBoy
# Checking timxjunior17
# https://oce.op.gg/summoner/userName=timxjunior17
# Checking donsky
# https://oce.op.gg/summoner/userName=donsky
# Checking Scottay44
# https://oce.op.gg/summoner/userName=Scottay44
# Checking Badgerbury
# https://oce.op.gg/summoner/userName=Badgerbury
# Checking Le Fatsheep
# https://oce.op.gg/summoner/userName=Le Fatsheep
# Checking A ZEBRA
# https://oce.op.gg/summoner/userName=A ZEBRA
# Checking Freeeeeelo
# https://oce.op.gg/summoner/userName=Freeeeeelo
# Checking SneakyGasm
# https://oce.op.gg/summoner/userName=SneakyGasm
# Checking Bakuma233
# https://oce.op.gg/summoner/userName=Bakuma233
# Checking Jàckal
# https://oce.op.gg/summoner/userName=Jàckal
# Checking SmallBlackTu
# https://oce.op.gg/summoner/userName=SmallBlackTu
# Checking caijing
# https://oce.op.gg/summoner/userName=caijing
# Checking Infate
# https://oce.op.gg/summoner/userName=Infate
# Checking Jamarcuscc
# https://oce.op.gg/summoner/userName=Jamarcuscc
# Checking Jarv1s
# https://oce.op.gg/summoner/userName=Jarv1s
# Checking eVAYSU
# https://oce.op.gg/summoner/userName=eVAYSU
# Checking írídescent
# https://oce.op.gg/summoner/userName=írídescent
# Checking Ayase
# https://oce.op.gg/summoner/userName=Ayase
# Checking Inspiritea
# https://oce.op.gg/summoner/userName=Inspiritea
# Checking archerHe
# https://oce.op.gg/summoner/userName=archerHe
# Checking Jawdzy
# https://oce.op.gg/summoner/userName=Jawdzy
# Checking BAZUKA
# https://oce.op.gg/summoner/userName=BAZUKA
# Checking beatslol
# https://oce.op.gg/summoner/userName=beatslol
# Checking BLC Director xie
# https://oce.op.gg/summoner/userName=BLC Director xie
# Checking Da Shi Xiong
# https://oce.op.gg/summoner/userName=Da Shi Xiong
# Checking WhiskeyDelta
# https://oce.op.gg/summoner/userName=WhiskeyDelta
# Checking SpookySnake
# https://oce.op.gg/summoner/userName=SpookySnake
# Checking MASINAE
# https://oce.op.gg/summoner/userName=MASINAE
# Checking dunny
# https://oce.op.gg/summoner/userName=dunny
# Checking oOJenOo
# https://oce.op.gg/summoner/userName=oOJenOo
# Checking Debo DAI
# https://oce.op.gg/summoner/userName=Debo DAI
# Checking The
# https://oce.op.gg/summoner/userName=The
# Checking TheProofyHD
# https://oce.op.gg/summoner/userName=TheProofyHD
# Checking The Samson
# https://oce.op.gg/summoner/userName=The Samson
# Checking BigRoddyTodd
# https://oce.op.gg/summoner/userName=BigRoddyTodd
# Checking THC View JC
# https://oce.op.gg/summoner/userName=THC View JC
# Checking mutant124
# https://oce.op.gg/summoner/userName=mutant124
# Checking mantIe
# https://oce.op.gg/summoner/userName=mantIe
# Checking Berrymilk
# https://oce.op.gg/summoner/userName=Berrymilk
# Checking MeAIHerFORsure
# https://oce.op.gg/summoner/userName=MeAIHerFORsure
# Checking h16
# https://oce.op.gg/summoner/userName=h16
# Checking jumba
# https://oce.op.gg/summoner/userName=jumba
# Checking Pleakley
# https://oce.op.gg/summoner/userName=Pleakley
# Checking Kevin Le
# https://oce.op.gg/summoner/userName=Kevin Le
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-48799c6096cd> in <module>()
#       8         break
#       9     print "Checking " + current_summoner["name"]
# ---> 10     CheckCurrentPlayer(current_summoner)
#
# <ipython-input-6-0fb8b554d1f2> in CheckCurrentPlayer(current_summoner)
#      39
#      40         detail_div = detail_soup.find("div", class_="GameDetailTableWrap")
# ---> 41         detail_tables = detail_div.find_all("table", class_="GameDetailTable")
#      42         blue_win = detail_tables[0].attrs['class'][1] == 'Result-WIN'
#      43
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
import json
import time
import random
import pymongo
import copy
import MyCommon
from pymongo import MongoClient
from collections import deque
import cassiopeia
from cassiopeia import riotapi
import numpy as np
from sklearn import preprocessing, cluster, decomposition
from scipy.cluster.vq import kmeans,vq
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans, AffinityPropagation
from sklearn.decomposition import FastICA, PCA
from sklearn import metrics
import matplotlib.pyplot as plt

riotapi.set_region("KR")
riotapi.set_api_key("79428a9e-5d98-469b-9b9b-429c1a750d24")
riotapi.set_rate_limits((10, 10), (500, 600))
riotapi.print_calls(True)

# %%
client = MongoClient()
loladb = client.loladb
summoners_collection = loladb.summoners
matches_collection = loladb.matches
print summoners_collection.count()
print matches_collection.count()
# Out:
# 1255
# 25615

# %%
champions = riotapi.get_champions()
dict_id2idx = dict()
dict_idx2id = dict()
dict_id2key = dict()
for a_idx, a_champion in enumerate(champions):
    champ_id = a_champion.id
    champ_key = a_champion.key
    dict_id2idx[champ_id] = a_idx
    dict_idx2id[a_idx] = champ_id
    dict_id2key[champ_id] = champ_key
    
#print dict_id2key[dict_idx2id[132]]
#print dict_id2key

def GetIdxFromId(a_id):
    return dict_id2idx[a_id]

def GetIdFromIdx(a_idx):
    return dict_idx2id[a_idx]

def GetNameFromId(a_id):
    return dict_id2key[a_id]
# Out:
# https://global.api.pvp.net/api/lol/static-data/kr/v1.2/champion?champData=all&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24
# https://global.api.pvp.net/api/lol/static-data/kr/v1.2/item?itemListData=all&api_key=79428a9e-5d98-469b-9b9b-429c1a750d24

# %%
def PrintMatchWithPair(blue_id, red_id):
    for a_idx, a_match in enumerate(matches_collection.find()):
        winning_side = -1
        if a_match['teams'][0]['winner'] == True and a_match['teams'][1]['winner'] == False:
            winning_side = 0
        if a_match['teams'][0]['winner'] == False and a_match['teams'][1]['winner'] == True:
            winning_side = 1 
        if winning_side == -1:
            return #do not count draw game, if any

        a_duration = a_match['matchDuration']
        a_minute = a_duration/60
        if a_minute <= 20:
            return #do not count surrendered game
        
        participants = a_match['participants']
        blues = [p['championId'] for p in participants[0:5]]
        reds = [p['championId'] for p in participants[5:10]]
        
        if blue_id in blues and red_id in reds:
            print "Match found with id " + a_match['matchId']

# %%
CHAMP_NUM = len(champions)
against_win_mat = np.zeros((CHAMP_NUM, CHAMP_NUM))
against_sum_mat = np.zeros((CHAMP_NUM, CHAMP_NUM))
synergy_win_mat = np.zeros((CHAMP_NUM, CHAMP_NUM))
synergy_sum_mat = np.zeros((CHAMP_NUM, CHAMP_NUM))
against_matrix = np.zeros((CHAMP_NUM, CHAMP_NUM))
synergy_matrix = np.zeros((CHAMP_NUM, CHAMP_NUM))

def SetWinningAgainst(a_blue_idx, a_red_idx, isWinning):
    #think the map is symmetric
    blue_idx = a_blue_idx
    red_idx = a_red_idx
    if a_blue_idx > a_red_idx:
        blue_idx = a_red_idx
        red_idx = a_blue_idx
    against_sum_mat[blue_idx, red_idx] += 1
    if isWinning:
        against_win_mat[blue_idx, red_idx] += 1
        
def SetWinningWith(a_idx, b_idx, isWinning):
    small_idx = a_idx
    large_idx = b_idx
    if a_idx > b_idx:
        small_idx = b_idx
        large_idx = a_idx
        
    synergy_sum_mat[small_idx, large_idx] += 1
    if isWinning:
        synergy_win_mat[small_idx, large_idx] += 1

def FillAgainstMatrix(blue_participants, red_participants, winning_side):
    for a_blue in blue_participants:
        blue_id = a_blue['championId']
        blue_idx = GetIdxFromId(blue_id)
        for a_red in red_participants:
            red_id = a_red['championId']
            red_idx = GetIdxFromId(red_id)
            isWinning = winning_side == 0
            SetWinningAgainst(blue_idx, red_idx, isWinning)
    
def FillSynergyMatrix(participants, isWinner):
    for a_participant in participants:
        champ_id = a_participant['championId']
        champ_idx = GetIdxFromId(champ_id)
        for another_part in participants:
            another_id = another_part['championId']
            another_idx = GetIdxFromId(another_id)
            if champ_id != another_id:
                SetWinningWith(champ_idx, another_idx, isWinner)

def FillMatrixFromMatch(a_match):
    #0 if blue win, 1 if red win
    winning_side = -1
    if a_match['teams'][0]['winner'] == True and a_match['teams'][1]['winner'] == False:
        winning_side = 0
    if a_match['teams'][0]['winner'] == False and a_match['teams'][1]['winner'] == True:
        winning_side = 1 
    if winning_side == -1:
        return #do not count draw game, if any
    
    a_duration = a_match['matchDuration']
    a_minute = a_duration/60
    if a_minute <= 20:
        return #do not count surrendered game
    
    participants = a_match['participants']
    
    has164 = False  
    for a_participant in participants:    
        if a_participant['championId'] == 164:
            has164 = True
    if has164:
        return    
    
    FillAgainstMatrix(participants[0:5], participants[5:10], winning_side)
    FillSynergyMatrix(participants[0:5], winning_side == 0)
    FillSynergyMatrix(participants[5:10], winning_side == 1)

for a_idx, a_match in enumerate(matches_collection.find()):
    FillMatrixFromMatch(a_match)
    if a_idx % 500 == 0:
        print a_idx
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500
# 10000
# 10500
# 11000
# 11500
# 12000
# 12500
# 13000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-18c19f554342> in <module>()
#      70
#      71 for a_idx, a_match in enumerate(matches_collection.find()):
# ---> 72     FillMatrixFromMatch(a_match)
#      73     if a_idx % 500 == 0:
#      74         print a_idx
#
# <ipython-input-6-18c19f554342> in FillMatrixFromMatch(a_match)
#      65
#      66     participants = a_match['participants']
# ---> 67     FillAgainstMatrix(participants[0:5], participants[5:10], winning_side)
#      68     FillSynergyMatrix(participants[0:5], winning_side == 0)
#      69     FillSynergyMatrix(participants[5:10], winning_side == 1)
#
# <ipython-input-6-18c19f554342> in FillAgainstMatrix(blue_participants, red_participants, winning_side)
#      35         for a_red in red_participants:
#      36             red_id = a_red['championId']
# ---> 37             red_idx = GetIdxFromId(red_id)
#      38             isWinning = winning_side == 0
#      39             SetWinningAgainst(blue_idx, red_idx, isWinning)
#
# <ipython-input-3-a66d0745b95e> in GetIdxFromId(a_id)
#      14
#      15 def GetIdxFromId(a_id):
# ---> 16     return dict_id2idx[a_id]
#      17
#      18 def GetIdFromIdx(a_idx):
#
# KeyError: 164

# %%
against_sum_mat[against_sum_mat == 0] = 1
synergy_sum_mat[synergy_sum_mat == 0] = 1
against_matrix = against_win_mat / against_sum_mat
synergy_matrix = synergy_win_mat / synergy_sum_mat

# %%
plt.imshow(against_matrix)
plt.colorbar(orientation='vertical')
plt.show()

# %%
plt.imshow(synergy_matrix)
plt.colorbar(orientation='vertical')
plt.show()

# %%
#print some highest / lowest samples in against matrix
print 133 * 132
print sum(sum(against_sum_mat > 50))
against_matrix_copy = against_matrix.copy()
against_matrix_copy[against_sum_mat < 50] = 0

synergy_matrix_copy = synergy_matrix.copy()
synergy_matrix_copy[synergy_sum_mat < 50] = 0

print sum(sum(against_matrix_copy > 0.65))
print sum(sum(np.logical_and(against_matrix_copy > 0, against_matrix_copy < 0.35)))

def PrintHighestPair(matrix_copy, high_thresh, sum_mat, content):
    highest_list = matrix_copy > high_thresh
    (highestX, highestY) = np.where(highest_list == True)
    
    for i in range(len(highestX)):
        print str(highestX[i]) + "-" + str(highestY[i])
        blue_champ = GetNameFromId(GetIdFromIdx(highestX[i]))
        red_champ = GetNameFromId(GetIdFromIdx(highestY[i]))
        print "%s: %s to %s with winrate %f in %d games" % (content, blue_champ, red_champ, 
                                                        matrix_copy[highestX[i], highestY[i]],
                                                       sum_mat[highestX[i], highestY[i]])
        
        if content == "Against":
            print "%s: %s to %s with winrate %f in %d games" % (content, red_champ, blue_champ, 
                                                            matrix_copy[highestY[i], highestX[i]],
                                                           sum_mat[highestY[i], highestX[i]])
PrintHighestPair(against_matrix_copy, 0.65, against_sum_mat, "Against")
PrintHighestPair(synergy_matrix_copy, 0.65, synergy_sum_mat, "Synergy")

def PrintLowestPair(matrix_copy, low_thresh, sum_mat, content):
    lower_list = np.logical_and(matrix_copy > 0, matrix_copy < low_thresh)
    (lX, lY) = np.where(lower_list == True)
    for i in range(len(lX)):
        blue_champ = GetNameFromId(GetIdFromIdx(lX[i]))
        red_champ = GetNameFromId(GetIdFromIdx(lY[i]))
        print "%s: %s to %s with winrate %f in %d games" % (content, blue_champ, red_champ, 
                                                        matrix_copy[lX[i], lY[i]],
                                                       sum_mat[lX[i], lY[i]])
        if content == "Against":
            print "%s: %s to %s with winrate %f in %d games" % (content, red_champ, blue_champ, 
                                                            matrix_copy[lY[i], lX[i]],
                                                           sum_mat[lY[i], lX[i]])

#print some highest / lowest samples in synergy matrix
    
PrintLowestPair(against_matrix_copy, 0.35, against_sum_mat, "Against")
PrintLowestPair(synergy_matrix_copy, 0.35, synergy_sum_mat, "Synergy")
# Out:
# 17556
# 1040
# 12
# 9
# 28-93
# Against: Twitch to Viktor with winrate 0.661017 in 59 games
# Against: Viktor to Twitch with winrate 0.443182 in 88 games
# 61-47
# Against: Rumble to Caitlyn with winrate 0.656250 in 64 games
# Against: Caitlyn to Rumble with winrate 0.536232 in 69 games
# 61-93
# Against: Rumble to Viktor with winrate 0.666667 in 57 games
# Against: Viktor to Rumble with winrate 0.435294 in 85 games
# 71-103
# Against: Ezreal to Lissandra with winrate 0.720000 in 50 games
# Against: Lissandra to Ezreal with winrate 0.528302 in 53 games
# 85-59
# Against: Shyvana to LeeSin with winrate 0.660000 in 50 games
# Against: LeeSin to Shyvana with winrate 0.527027 in 74 games
# 85-71
# Against: Shyvana to Ezreal with winrate 0.666667 in 54 games
# Against: Ezreal to Shyvana with winrate 0.511111 in 90 games
# 91-42
# Against: Varus to Karma with winrate 0.666667 in 54 games
# Against: Karma to Varus with winrate 0.590909 in 66 games
# 91-59
# Against: Varus to LeeSin with winrate 0.688525 in 61 games
# Against: LeeSin to Varus with winrate 0.441176 in 68 games
# 102-6
# Against: Jayce to Leblanc with winrate 0.660377 in 53 games
# Against: Leblanc to Jayce with winrate 0.464286 in 56 games
# 112-71
# Against: Velkoz to Ezreal with winrate 0.655172 in 58 games
# Against: Ezreal to Velkoz with winrate 0.464286 in 56 games
# 122-108
# Against: Ekko to Zyra with winrate 0.740000 in 50 games
# Against: Zyra to Ekko with winrate 0.000000 in 49 games
# 130-71
# Against: Ivern to Ezreal with winrate 0.661017 in 59 games
# Against: Ezreal to Ivern with winrate 0.444444 in 63 games
# 6-68
# Synergy: Leblanc to Poppy with winrate 0.656566 in 99 games
# 12-129
# Synergy: Ryze to RekSai with winrate 0.666667 in 129 games
# 39-106
# Synergy: Janna to Syndra with winrate 0.728814 in 59 games
# 68-6
# Synergy: Poppy to Leblanc with winrate 0.656566 in 99 games
# 78-129
# Synergy: Malzahar to RekSai with winrate 0.666667 in 57 games
# 88-129
# Synergy: Fizz to RekSai with winrate 0.703704 in 54 games
# 106-39
# Synergy: Syndra to Janna with winrate 0.728814 in 59 games
# 129-12
# Synergy: RekSai to Ryze with winrate 0.666667 in 129 games
# 129-78
# Synergy: RekSai to Malzahar with winrate 0.666667 in 57 games
# 129-88
# Synergy: RekSai to Fizz with winrate 0.703704 in 54 games
# Against: Ryze to Elise with winrate 0.333333 in 51 games
# Against: Elise to Ryze with winrate 0.372549 in 51 games
# Against: Corki to Karma with winrate 0.344262 in 61 games
# Against: Karma to Corki with winrate 0.516129 in 62 games
# Against: Blitzcrank to Graves with winrate 0.339623 in 53 games
# Against: Graves to Blitzcrank with winrate 0.535714 in 56 games
# Against: Katarina to Caitlyn with winrate 0.346154 in 52 games
# Against: Caitlyn to Katarina with winrate 0.500000 in 58 games
# Against: Cassiopeia to Ryze with winrate 0.342466 in 73 games
# Against: Ryze to Cassiopeia with winrate 0.408451 in 71 games
# Against: Graves to Twitch with winrate 0.326923 in 52 games
# Against: Twitch to Graves with winrate 0.467742 in 62 games
# Against: Viktor to Maokai with winrate 0.321678 in 143 games
# Against: Maokai to Viktor with winrate 0.523438 in 128 games
# Against: Jayce to Twitch with winrate 0.342466 in 73 games
# Against: Twitch to Jayce with winrate 0.000000 in 46 games
# Against: Lucian to Elise with winrate 0.343750 in 64 games
# Against: Elise to Lucian with winrate 0.440678 in 59 games
# Synergy: Blitzcrank to Yasuo with winrate 0.321429 in 56 games
# Synergy: Fiora to Khazix with winrate 0.347826 in 69 games
# Synergy: Khazix to Fiora with winrate 0.347826 in 69 games
# Synergy: Yasuo to Blitzcrank with winrate 0.321429 in 56 games

# %%
print against_matrix_copy[122, 108]
print against_sum_mat[108, 122]
print against_matrix_copy[108, 122]
# Out:
# 0.74
# 49.0
# 0.0

# %%
#Check blue Twitch to red Jayce bug?
def CheckChampID():
    for each_id in dict_id2key:
        if dict_id2key[each_id] == "Jayce":
            print "Id for Jayce"
            print each_id
        if dict_id2key[each_id] == "Twitch":
            print "Id for Twitch"
            print each_id
twitch_id = 29
jayce_id = 126

def CheckTwitchToJayce():
    for a_idx, a_match in enumerate(matches_collection.find()):
        participants = a_match['participants']
        blues = [p['championId'] for p in participants[0:5]]
        reds = [p['championId'] for p in participants[5:10]]
        
        if twitch_id in blues and jayce_id in reds:
            print str(a_match['teams'][0]['winner']) + "-" + str(a_match['teams'][1]['winner'])
    
#CheckTwitchToJayce()
twitch_idx = GetIdxFromId(twitch_id)
jayce_idx = GetIdxFromId(jayce_id)
print against_win_mat[twitch_idx, jayce_idx]
print against_sum_mat[twitch_idx, jayce_idx]
# Out:
# 22.0
# 46.0
